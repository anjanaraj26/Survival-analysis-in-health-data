# %% [markdown]
# # Model Evaluation (Survival)
#
# This notebook evaluates and compares survival models (e.g., Cox PH and Random Survival Forest)
# using standard survival metrics.
#
# **Note:** Raw data are not included in this repository. See `data/README.md` for access notes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data (see data/README.md)
df = None  # placeholder

# Expected columns:
# time  -> duration
# event -> 0/1
# plus covariates

# %% [markdown]
# ## Evaluation Metrics
#
# - **Concordance Index (C-index):** discrimination (higher is better)
# - **Risk stratification:** compare survival curves in low/medium/high risk groups
# - **Calibration (optional):** agreement between predicted and observed survival

# %%
print("Evaluation placeholder: C-index requires model predictions + data.")
print("When ready, compute C-index using lifelines or scikit-survival.")
# Out:
# Evaluation placeholder: C-index requires model predictions + data.
# When ready, compute C-index using lifelines or scikit-survival.

# %% [markdown]
# ## Risk Stratification (Plan)
#
# 1. Compute a risk score for each individual (e.g., Cox partial hazard or RSF risk).
# 2. Split into quantiles (e.g., tertiles: low/medium/high risk).
# 3. Plot Kaplan–Meier curves by risk group.

# %%
print("KM curves placeholder (requires lifelines KaplanMeierFitter + risk groups).")
# Out:
# KM curves placeholder (requires lifelines KaplanMeierFitter + risk groups).
